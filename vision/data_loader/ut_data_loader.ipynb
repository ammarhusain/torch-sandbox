# %%
#%load_ext autoreload
#%autoreload 2

#from mit_scene_parsing import MITSceneParsingLoader
#k = MITSceneParsingLoader()
#print(f"k num cls: {k.n_classes}")

#print(k.files[15828])
#img = Image.open(k.files[15828])
#img.show()
#img, annt = k[15828]
#print(img.shape)
#print(annt.shape)


from PIL import Image
#Image.fromarray(img, 'RGB').show()
#print(img.shape)
#Image.fromarray(annt).show()

import torch

# %%
# %load_ext autoreload
# %autoreload 2

from simulated_data import SimulatedDataLoader
import numpy as np
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt

np.random.seed(1234)

sdl = SimulatedDataLoader(n_imgs=10)


print(sdl.n_classes)

img, annt = sdl.get_viz(*sdl[4])




# %matplotlib inline
f, axarr = plt.subplots(2)
axarr[0].imshow(img)
axarr[1].imshow(annt)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Generating 10 images
# 10

# %%
# %load_ext autoreload
# %autoreload 2

from mnist import NoisyMNISTDataLoader, MNISTDataLoader
import numpy as np
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt

np.random.seed(1234)
print("entering dataloader")
sdl = MNISTDataLoader()
img, lbl = sdl[4]

nsdl = NoisyMNISTDataLoader()
nimg, nlbl = nsdl[4]


# %matplotlib inline
f, axarr = plt.subplots(3)
axarr[0].imshow(img.squeeze())
axarr[1].imshow(nimg.squeeze())
axarr[2].imshow(nlbl.squeeze())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# entering dataloader
# Generating 60000 images
# Generating 60000 images

# %%
# %load_ext autoreload
# %autoreload 2

from fashion_mnist import NoisyFashionMNISTDataLoader, FashionMNISTDataLoader
import numpy as np
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt
import random

np.random.seed(1234)
print("entering dataloader")
sdl = FashionMNISTDataLoader()
idx = random.randint(0,len(sdl))
img, lbl = sdl[idx]

nsdl = NoisyFashionMNISTDataLoader()
nimg, nlbl = nsdl[idx]


# %matplotlib inline
f, axarr = plt.subplots(3)
axarr[0].imshow(img.squeeze())
axarr[1].imshow(nimg.squeeze())
axarr[2].imshow(nlbl.squeeze())
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# entering dataloader
# Generating 60000 images
# Generating 60000 images

# %%
# %load_ext autoreload
# %autoreload 2

from celeb_a_faces import CelebAFacesDataLoader
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils
import torch

c = CelebAFacesDataLoader()

dataloader = torch.utils.data.DataLoader(c, batch_size=100,
                                         shuffle=True)
real_batch = next(iter(dataloader))
                                         
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0][:64], padding=2,
                                        normalize=True), (1,2,0)))
# Out:
# Generating 202599 images

# %%
# %load_ext autoreload
# %autoreload 2

from anime_faces import AnimeFacesDataLoader
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils
import torch

c = AnimeFacesDataLoader()

dataloader = torch.utils.data.DataLoader(c, batch_size=100,
                                         shuffle=True)
real_batch = next(iter(dataloader))
                                         
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0][:64], padding=2,
                                        normalize=True), (1,2,0)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Generating 63565 images

# %%
# %load_ext autoreload
# %autoreload 2

from faces import FacesDataLoader
from PIL import Image
from matplotlib.pyplot import imshow
from IPython import display
import matplotlib.pyplot as plt
import numpy as np
import torchvision.utils as vutils
import torch

c = FacesDataLoader()

dataloader = torch.utils.data.DataLoader(c, batch_size=100,
                                         shuffle=True)
real_batch = next(iter(dataloader))
                                         
plt.figure(figsize=(8,8))
plt.axis("off")
plt.title("Training Images")
plt.imshow(np.transpose(vutils.make_grid(real_batch[0][:64], padding=2,
                                        normalize=True), (1,2,0)))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Generating 266164 images
